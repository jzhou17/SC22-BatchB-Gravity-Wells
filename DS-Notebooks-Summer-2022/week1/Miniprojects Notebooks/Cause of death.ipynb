# %%
import pandas as pd
import plotly.express as px #importing plotly

# %%
cod = pd.read_csv("Caused of Deaths.csv")

# %%
cod
# Out:
#                     Country ISO_CODE  Year  Deaths                   Cause  \
# 0               Afghanistan      AFG  1980   35000  Conflict and Terrorism
# 1                   Albania      ALB  1980       0  Conflict and Terrorism
# 2                   Algeria      DZA  1980       0  Conflict and Terrorism
# 3            American Samoa      ASM  1980       0  Conflict and Terrorism
# 4                    Angola      AGO  1980    5882  Conflict and Terrorism
# ...                     ...      ...   ...     ...                     ...
# 36855               Vietnam      VNM  2017       0          Other Injuries
# 36856  Virgin Islands, U.S.      VGB  2017       0          Other Injuries
# 36857                 Yemen      YEM  2017      21          Other Injuries
# 36858                Zambia      ZMB  2017       0          Other Injuries
# 36859              Zimbabwe      ZWE  2017      64          Other Injuries
#
#          Male POP  Female POP   Total Pop           GDP         PCAP
# ...

# %%
cod.Cause.unique()
# Out:
# array(['Conflict and Terrorism', 'Epidemics', 'Famine',
#        'Natural Disaster', 'Other Injuries'], dtype=object)

# %%
cod = cod[cod.Country == 'United States']

# %%
cod
# Out:
#              Country ISO_CODE  Year  Deaths                   Cause  \
# 184    United States      USA  1980      37  Conflict and Terrorism
# 378    United States      USA  1981      30  Conflict and Terrorism
# 572    United States      USA  1982      14  Conflict and Terrorism
# 766    United States      USA  1983     435  Conflict and Terrorism
# 960    United States      USA  1984      35  Conflict and Terrorism
# ...              ...      ...   ...     ...                     ...
# 36074  United States      USA  2013      92          Other Injuries
# 36268  United States      USA  2014      25          Other Injuries
# 36462  United States      USA  2015      37          Other Injuries
# 36656  United States      USA  2016       0          Other Injuries
# 36850  United States      USA  2017      90          Other Injuries
#
#           Male POP   Female POP    Total Pop           GDP          PCAP
# 184    111417847.0  115807153.0  227225000.0  2.857307e+12  12574.791506
# ...

# %%
cod = cod[cod.Deaths < 1500]

# %%
fig = px.line(cod, x = "Year", y = "Deaths", color = "Cause")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
