# %%
import pandas as pd

# %%
df = pd.read_csv("emissions_dataset.csv");

# %%
df.head()
# Out:
#    Greenhouse Gas Emissions Country  Year  Hard Coal Production  \
# 0             423672.224546     AUS  1990              141792.0
# 1             423733.063876     AUS  1991              152905.0
# 2             427426.084255     AUS  1992              159616.0
# 3             428337.072227     AUS  1993              160360.0
# 4             428818.220667     AUS  1994              156324.0
#
#    Natural Gas Production  Crude Oil Production  Motor Gasoline Production  \
# 0                797340.0               25465.0                    11969.0
# 1                829256.0               25432.0                    12098.0
# 2                902611.0               22311.0                    12640.0
# 3                970864.0               21836.0                    13020.0
# 4               1046133.0               20262.0                    13023.0
#
#    Gas Oil/Diesel Oil Production  Hard Coal Import  Natural Gas Import  \
# ...

# %%
df.tail()
# Out:
#       Greenhouse Gas Emissions Country  Year  Hard Coal Production  \
# 1285              6.671112e+06     USA  2015              366929.0
# 1286              6.520338e+06     USA  2016              294084.0
# 1287              6.483291e+06     USA  2017              319598.0
# 1288              6.671449e+06     USA  2018              325132.0
# 1289              6.558345e+06     USA  2019              309416.0
#
#       Natural Gas Production  Crude Oil Production  Motor Gasoline Production  \
# 1285             29617817.00              464056.0                 349073.000
# 1286             29182769.00              438053.0                 360503.000
# 1287             29850875.00              461267.0                 363315.989
# 1288             32766494.79              542095.4                 368024.675
# 1289             37212841.00              604125.5                 360563.398
#
#       Gas Oil/Diesel Oil Production  Hard Coal Import  Natural Gas Import  \
# ...

# %%
import plotly.express as px

# %%
fig1 = px.scatter(df, x="Year", y="Natural Gas Export", color="Natural Gas Import")
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.scatter(df, x="Year", y="Crude Oil Export", color="Crude Oil Import", height=350)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.imshow(df.corr(), width=800, height=800)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np

# %%
from sklearn.metrics import mean_absolute_error
