# %%
import pandas as pd
import plotly.express as pl

# %%
df = pd.read_csv("emissions_dataset.csv")
df
# Out:
#       Greenhouse Gas Emissions Country  Year  Hard Coal Production  \
# 0                 4.236722e+05     AUS  1990              141792.0
# 1                 4.237331e+05     AUS  1991              152905.0
# 2                 4.274261e+05     AUS  1992              159616.0
# 3                 4.283371e+05     AUS  1993              160360.0
# 4                 4.288182e+05     AUS  1994              156324.0
# ...                        ...     ...   ...                   ...
# 1285              6.671112e+06     USA  2015              366929.0
# 1286              6.520338e+06     USA  2016              294084.0
# 1287              6.483291e+06     USA  2017              319598.0
# 1288              6.671449e+06     USA  2018              325132.0
# 1289              6.558345e+06     USA  2019              309416.0
#
#       Natural Gas Production  Crude Oil Production  Motor Gasoline Production  \
# 0                  797340.00               25465.0                  11969.000
# ...

# %%
MAX_MISSING = 5
df.drop(df[df.isnull().sum(axis=1)>MAX_MISSING].index,axis=0,inplace=True)
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Greenhouse Gas Emissions       816 non-null    float64
#  1   Country                        816 non-null    object
#  2   Year                           816 non-null    int64
#  3   Hard Coal Production           451 non-null    float64
#  4   Natural Gas Production         731 non-null    float64
#  5   Crude Oil Production           722 non-null    float64
#  6   Motor Gasoline Production      813 non-null    float64
#  7   Gas Oil/Diesel Oil Production  813 non-null    float64
#  8   Hard Coal Import               796 non-null    float64
#  9   Natural Gas Import             742 non-null    float64
#  10  Crude Oil Import               810 non-null    float64
#  11  Motor Gasoline Import          808 non-null    float64
# ...

# %%
df["Country"].unique()
# Out:
# array(['AUS', 'AUT', 'BEL', 'BGR', 'BLR', 'CAN', 'CZE', 'DEU', 'DNK',
#        'ESP', 'FIN', 'GBR', 'GRC', 'HRV', 'HUN', 'IRL', 'JPN', 'LTU',
#        'NLD', 'NZL', 'POL', 'ROU', 'RUS', 'SVK', 'SVN', 'SWE', 'TUR',
#        'UKR', 'USA'], dtype=object)

# %%
fig = pl.scatter(df, x="Year", y="Natural Gas Production", size="Greenhouse Gas Emissions", color = "Country", title="Natural Gas Production of Different Countries Over Time")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = pl.scatter(df, x="Year", y="Crude Oil Production", size="Greenhouse Gas Emissions", color = "Country", title="Crude Oil Production of Different Countries Over Time")
fig.write_html('./Charts/Crude Oil Production of Different Countries Over Time.html')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = pl.scatter(df, x="Year", y="Hard Coal Production", size="Greenhouse Gas Emissions", color = "Country", title="Hard Coal Production of Different Countries Over Time")
fig.write_html('./Charts/Hard Coal Production of Different Countries Over Time.html')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pl.scatter(df, x="Year", y="Motor Gasoline Production", size="Greenhouse Gas Emissions", color = "Country", title="Motor Gasoline Production of Different Countries Over Time")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = pl.imshow(df.corr(),title="Correlation Matrix",width=650,height=650)
fig.update_xaxes(tickangle=-45)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_1999 = df[df["Year"]==1999]
df_2009 = df[df["Year"]==2009]
df_2019 = df[df["Year"]==2019]

# %%
GHG_total_1999 = df_1999["Greenhouse Gas Emissions"].sum()
GHG_total_2009 = df_2009["Greenhouse Gas Emissions"].sum()
GHG_total_2019 = df_2019["Greenhouse Gas Emissions"].sum()

# %%
GHG_totals = []
year = 1990
while year<=2019:
    dfx = df[df['Year']==year]
    GHG_totals.append(dfx['Greenhouse Gas Emissions'].sum())
    year+=1
GHG_totals
# Out:
# [24676152.13305726,
#  24169588.55047349,
#  23435711.327728096,
#  23120772.51290008,
#  22837207.9138477,
#  22976656.637277015,
#  23380504.38569496,
#  23141450.52546512,
#  23029892.253255866,
#  22895385.745395772,
#  23112225.19940181,
#  23114525.18969114,
#  23083626.846285187,
#  23410716.997186292,
#  23566411.75623473,
#  23553906.386257954,
#  23529744.560891554,
#  23628466.176275678,
#  23103321.10792888,
#  21597235.088828098,
#  22201620.9518862,
#  21897391.655618206,
#  21625081.375456966,
#  21547009.685557373,
#  21164330.64560289,
#  21007102.266675137,
#  20833080.979984045,
#  20875716.311667103,
#  20920063.535057075,
#  20400701.42938479]
