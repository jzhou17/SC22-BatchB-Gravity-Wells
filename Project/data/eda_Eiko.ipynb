# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("~/Project/data/emissions_clean.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Greenhouse Gas Emissions       816 non-null    float64
#  1   Country                        816 non-null    object
#  2   Year                           816 non-null    float64
#  3   Natural Gas Production         816 non-null    float64
#  4   Crude Oil Production           816 non-null    float64
#  5   Motor Gasoline Production      816 non-null    float64
#  6   Gas Oil/Diesel Oil Production  816 non-null    float64
#  7   Hard Coal Import               816 non-null    float64
#  8   Natural Gas Import             816 non-null    float64
#  9   Crude Oil Import               816 non-null    float64
#  10  Motor Gasoline Import          816 non-null    float64
#  11  Gas Oil/Diesel Oil Import      816 non-null    float64
# ...

# %%
df.head()
# Out:
#    Greenhouse Gas Emissions Country  Year  Hard Coal Production  \
# 0             423672.224546     AUS  1990              141792.0
# 1             423733.063876     AUS  1991              152905.0
# 2             427426.084255     AUS  1992              159616.0
# 3             428337.072227     AUS  1993              160360.0
# 4             428818.220667     AUS  1994              156324.0
#
#    Natural Gas Production  Crude Oil Production  Motor Gasoline Production  \
# 0                797340.0               25465.0                    11969.0
# 1                829256.0               25432.0                    12098.0
# 2                902611.0               22311.0                    12640.0
# 3                970864.0               21836.0                    13020.0
# 4               1046133.0               20262.0                    13023.0
#
#    Gas Oil/Diesel Oil Production  Hard Coal Import  Natural Gas Import  \
# ...

# %%
len(df)
# Out:
# 1290

# %%
columns_to_remove = ['Hard Coal Export', 'Natural Gas Export', "Crude Oil Export", 'Hard Coal Production' , 'Natural Gas Production' , "Crude Oil Production", "Unnamed: 0"]
df.drop(columns_to_remove, axis = 1, inplace = True)
df.head()
# Out:
#    Greenhouse Gas Emissions  Year  Motor Gasoline Production  \
# 0             423672.224546  1990                    11969.0
# 1             423733.063876  1991                    12098.0
# 2             427426.084255  1992                    12640.0
# 3             428337.072227  1993                    13020.0
# 4             428818.220667  1994                    13023.0
#
#    Gas Oil/Diesel Oil Production  Hard Coal Import  Natural Gas Import  \
# 0                         8700.0               NaN                 NaN
# 1                         8702.0               NaN                 NaN
# 2                         8794.0               NaN                 NaN
# 3                         9311.0               NaN                 NaN
# 4                         9748.0               NaN                 NaN
#
#    Crude Oil Import  Motor Gasoline Import  Gas Oil/Diesel Oil Import  \
# 0            6039.0                 1166.0                      871.0
# ...

# %%
# Show correlation matrix
fig = px.imshow(df.corr(),title="Correlation Matrix",width=650,height=650)
fig.update_xaxes(tickangle=-45)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df, x = "Year", y = "Greenhouse Gas Emissions", color = "Country", title = "Greenhouse Gas Emissions v. Time")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df[df.Country == "RUS"], x = "Year", y = "Greenhouse Gas Emissions")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y2019 = df[df.Year == 2019]

# %%
other = y2019[y2019.country]

# %%
fig = px.pie(df, values = "Natural Gas Import", names = "Country", title= 'Natural Gas Imports by country')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df, values = "Natural Gas Export", names = "Country", title= 'Natural Gas Exports by country')
fig.show()

# %%
fig = px.scatter(df, x = "Year", y = "Greenhouse Gas Emissions", color = "Country")
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
