# %%
import numpy as np
import pandas as pd
import sklearn
import plotly.express as px
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
# Get data
df = pd.read_csv('../data/emissions_clean.csv')
df.drop('Country', axis=1, inplace=True)
df.dropna(inplace=True)
target = df.pop('Greenhouse Gas Emissions')
inputs_train, inputs_test, outputs_train, outputs_test = train_test_split(df, target, test_size=0.2)

# %%
# Lasso Regression
LASSO=linear_model.Lasso(alpha=0.0001, fit_intercept=True, selection='random')
LASSO.fit(inputs_train, outputs_train)
# Out:
# Lasso(alpha=0.0001, selection='random')

# %%
# Linear Regression
LR = LinearRegression()
LR.fit(inputs_train, outputs_train)
# Out:
# LinearRegression()

# %%
# Elastic Net
EN = linear_model.ElasticNet(alpha = 1e-08, fit_intercept = True, l1_ratio = 0.9, selection = 'random')
EN.fit(inputs_train, outputs_train)
# Out:
# ElasticNet(alpha=1e-08, l1_ratio=0.9, selection='random')

# %%
# Random Forest
RFR = RandomForestRegressor(150,min_samples_split=3)
RFR.fit(inputs_train, outputs_train)
# Out:
# RandomForestRegressor(min_samples_split=3, n_estimators=150)

# %%
# KNN
from sklearn.neighbors import KNeighborsRegressor
KNN = KNeighborsRegressor(n_neighbors=2, weights='distance')
KNN.fit(inputs_train, outputs_train)
# Out:
# KNeighborsRegressor(n_neighbors=2, weights='distance')

# %%
# Get results
# Actual is outputs_test
lasso_res = LASSO.predict(inputs_test)
lr_res = LR.predict(inputs_test)
en_res = EN.predict(inputs_test)
rfr_res = RFR.predict(inputs_test)
knn_res = KNN.predict(inputs_test)

# %%
# Plot
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=2, cols=3)

fig.add_trace(
    go.Scatter(x=lasso_res, y=outputs_test,
    mode='markers',
    name='Lasso'),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=lr_res, y=outputs_test,
    mode='markers',
    name='Linear Regression'),
    row=1, col=2
)


fig.add_trace(
    go.Scatter(x=en_res, y=outputs_test,
    mode='markers',
    name='Elastic Net'),
    row=1, col=3
)


fig.add_trace(
    go.Scatter(x=rfr_res, y=outputs_test,
    mode='markers',
    name='Random Forest Regression'),
    row=2, col=1
)



fig.add_trace(
    go.Scatter(x=knn_res, y=outputs_test,
    mode='markers',
    name='K-Nearest Neighbors'),
    row=2, col=2
)

fig.update_layout(height=600, width=1200, title_text="ML Results Visual Comparison")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="db0f99c9-ed32-4e2b-8eb6-4dde2d6cd51c" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db0f99c9-ed32-4e2b-8eb6-4dde2d6cd51c")) {                    Plotly.newPlot(                        "db0f99c9-ed32-4e2b-8eb6-4dde2d6cd51c",                        [{"mode":"markers","name":"Lasso","x":[0.024563929006723585,0.024003008770524345,0.028601758254056836,0.008912104844577017,0.03522806555873215,0.019197167785592467,0.11621898006827298,0.9456049258316662,0.9102480190307126,0.0263013969225033,0.01708261952278741,0.023609026759604194,0.01035321407824914,0.02200662198277992,0.0014026743595056766,-0.0022820930033608574,-0.001554425950536592,0.05142114854586506,0.09533185265